# %% [markdown]
# 4. Con el uso de librerías en PYTHON, construya la dependencia de Abuelos, tios, padres, primos e hijos de su familia.

# %%
from kanren import Relation, facts, run, var
x = var()

padres = Relation()
facts(padres, ("Pascual", "Eddy"),
              ("Pascual", "Angel"),
              ("Pascual", "Roger"),
              ("Pascual", "Reynaldo"),
              ("Norah", "Eddy"),
              ("Norah", "Angel"),
              ("Norah", "Roger"),
              ("Norah", "Reynaldo"),

              ("Ancelmo", "Julia"),
              ("Ancelmo", "Cristina"),
              ("Ancelmo", "Miguel"),
              ("Ancelmo", "Rene"),
              ("Ancelmo", "Nansy"),
              ("Ancelmo", "Juana"),
              ("Isabel", "Julia"),
              ("Isabel", "Cristina"),
              ("Isabel", "Miguel"),
              ("Isabel", "Rene"),
              ("Isabel", "Nansy"),
              ("Isabel", "Juana"),

              ("Eddy", "Rodrigo"),
              ("Eddy", "Mariela"),
              ("Julia", "Rodrigo"),
              ("Julia", "Mariela"),

              ("Roger", "Jhenny"),
              ("Roger", "Nayely"),
              ("Hilda", "Jhenny"),
              ("Hilda", "Nayely"),

              ("Reynaldo", "Belisario"),
              ("Karen", "Belisario"),

              ("Migel", "Cristian"),
              ("Migel", "Brayan"),
              ("Cristina", "Cristian"),
              ("Cristina", "Brayan"),

              ("Miguel", "Ivan"),
              ("Miguel", "Yoseline"),
              ("Crissthina", "Ivan"),
              ("Crissthina", "Yoseline"),

              ("Rene", "Yessica"),
              ("Berta", "Yessica"),

              ("Eduardo", "Ever"),
              ("Eduardo", "Guisela"),
              ("Nansy", "Ever"),
              ("Nansy", "Guisela"),

              ("Idelfonso", "Maria"),
              ("Idelfonso", "Dario"),
              ("Juana", "Maria"),
              ("Juana", "Dario"))

abuelos = Relation()
facts(abuelos,  ("Pascual", "Rodrigo"),
                ("Pascual", "Mariela"),
                ("Pascual", "Jhenny"),
                ("Pascual", "Nayely"),
                ("Pascual", "Belisario"),
                ("Norah", "Rodrigo"),
                ("Norah", "Mariela"),
                ("Norah", "Jhenny"),
                ("Norah", "Nayely"),
                ("Norah", "Belisario"),

                ("Ancelmo", "Rodrigo"),
                ("Ancelmo", "Mariela"),
                ("Ancelmo", "Cristian"),
                ("Ancelmo", "Brayan"),
                ("Ancelmo", "Ivan"),
                ("Ancelmo", "Yoseline"),
                ("Ancelmo", "Yessica"),
                ("Ancelmo", "Ever"),
                ("Ancelmo", "Guisela"),
                ("Ancelmo", "Maria"),
                ("Ancelmo", "Dario"),
                ("Isabel", "Rodrigo"),
                ("Isabel", "Mariela"),
                ("Isabel", "Cristian"),
                ("Isabel", "Brayan"),
                ("Isabel", "Ivan"),
                ("Isabel", "Yoseline"),
                ("Isabel", "Yessica"),
                ("Isabel", "Ever"),
                ("Isabel", "Guisela"),
                ("Isabel", "Maria"),
                ("Isabel", "Dario"),)

tios = Relation()
facts(tios, ("Angel", "Rodrigo"),
            ("Angel", "Mariela"),
            ("Angel", "Jhenny"),
            ("Angel", "Nayely"),
            ("Angel", "Belisario"),

            ("Roger", "Rodrigo"),
            ("Roger", "Mariela"),
            ("Roger", "Belisario"),
            ("Hilda", "Rodrigo"),
            ("Hilda", "Mariela"),
            ("Hilda", "Belisario"),

            ("Reynaldo", "Rodrigo"),
            ("Reynaldo", "Mariela"),
            ("Reynaldo", "Jhenny"),
            ("Reynaldo", "Nayely"),
            ("Karen", "Rodrigo"),
            ("Karen", "Mariela"),
            ("Karen", "Jhenny"),
            ("Karen", "Nayely"),

            ("Eddy", "Jhenny"),
            ("Eddy", "Nayely"),
            ("Eddy", "Belisario"),
            ("Julia", "Jhenny"),
            ("Julia", "Nayely"),
            ("Julia", "Belisario"),

            ("Migel", "Rodrigo"),
            ("Migel", "Mariela"),
            ("Migel", "Ivan"),
            ("Migel", "Yoseline"),
            ("Migel", "Yessica"),
            ("Migel", "Ever"),
            ("Migel", "Guisela"),
            ("Migel", "Maria"),
            ("Migel", "Dario"),
            ("Cristina", "Rodrigo"),
            ("Cristina", "Mariela"),
            ("Cristina", "Ivan"),
            ("Cristina", "Yoseline"),
            ("Cristina", "Yessica"),
            ("Cristina", "Ever"),
            ("Cristina", "Guisela"),
            ("Cristina", "Maria"),
            ("Cristina", "Dario"),

            ("Miguel", "Rodrigo"),
            ("Miguel", "Mariela"),
            ("Miguel", "Cristian"),
            ("Miguel", "Brayan"),
            ("Miguel", "Yessica"),
            ("Miguel", "Ever"),
            ("Miguel", "Guisela"),
            ("Miguel", "Maria"),
            ("Miguel", "Dario"),
            ("Crissthina", "Rodrigo"),
            ("Crissthina", "Mariela"),
            ("Crissthina", "Cristian"),
            ("Crissthina", "Brayan"),
            ("Crissthina", "Yessica"),
            ("Crissthina", "Ever"),
            ("Crissthina", "Guisela"),
            ("Crissthina", "Maria"),
            ("Crissthina", "Dario"),

            ("Rene", "Rodrigo"),
            ("Rene", "Mariela"),
            ("Rene", "Cristian"),
            ("Rene", "Brayan"),
            ("Rene", "Ivan"),
            ("Rene", "Yoseline"),
            ("Rene", "Ever"),
            ("Rene", "Guisela"),
            ("Rene", "Maria"),
            ("Rene", "Dario"),
            ("Berta", "Rodrigo"),
            ("Berta", "Mariela"),
            ("Berta", "Cristian"),
            ("Berta", "Brayan"),
            ("Berta", "Ivan"),
            ("Berta", "Yoseline"),
            ("Berta", "Ever"),
            ("Berta", "Guisela"),
            ("Berta", "Maria"),
            ("Berta", "Dario"),

            ("Eduardo", "Rodrigo"),
            ("Eduardo", "Mariela"),
            ("Eduardo", "Cristian"),
            ("Eduardo", "Brayan"),
            ("Eduardo", "Ivan"),
            ("Eduardo", "Yoseline"),
            ("Eduardo", "Yessica"),
            ("Eduardo", "Maria"),
            ("Eduardo", "Dario"),
            ("Nansy", "Rodrigo"),
            ("Nansy", "Mariela"),
            ("Nansy", "Cristian"),
            ("Nansy", "Brayan"),
            ("Nansy", "Ivan"),
            ("Nansy", "Yoseline"),
            ("Nansy", "Yessica"),
            ("Nansy", "Maria"),
            ("Nansy", "Dario"),

            ("Idelfonso", "Rodrigo"),
            ("Idelfonso", "Mariela"),
            ("Idelfonso", "Cristian"),
            ("Idelfonso", "Brayan"),
            ("Idelfonso", "Ivan"),
            ("Idelfonso", "Yoseline"),
            ("Idelfonso", "Yessica"),
            ("Idelfonso", "Ever"),
            ("Idelfonso", "Guisela"),
            ("Juana", "Rodrigo"),
            ("Juana", "Mariela"),
            ("Juana", "Cristian"),
            ("Juana", "Brayan"),
            ("Juana", "Ivan"),
            ("Juana", "Yoseline"),
            ("Juana", "Yessica"),
            ("Juana", "Ever"),
            ("Juana", "Guisela"),

            ("Eddy", "Maria"),
            ("Eddy", "Dario"),
            ("Eddy", "Cristian"),
            ("Eddy", "Brayan"),
            ("Eddy", "Ivan"),
            ("Eddy", "Yoseline"),
            ("Eddy", "Yessica"),
            ("Eddy", "Ever"),
            ("Eddy", "Guisela"),
            ("Julia", "Maria"),
            ("Julia", "Dario"),
            ("Julia", "Cristian"),
            ("Julia", "Brayan"),
            ("Julia", "Ivan"),
            ("Julia", "Yoseline"),
            ("Julia", "Yessica"),
            ("Julia", "Ever"),
            ("Julia", "Guisela"))

primos = Relation()
facts(primos, ("Rodrigo", "Cristian"),
              ("Rodrigo", "Brayan"),
              ("Rodrigo", "Ivan"),
              ("Rodrigo", "Yoseline"),
              ("Rodrigo", "Yessica"),
              ("Rodrigo", "Ever"),
              ("Rodrigo", "Guisela"),
              ("Rodrigo", "Maria"),
              ("Rodrigo", "Dario"),
              ("Rodrigo", "Belisario"),
              ("Rodrigo", "Jhenny"),
              ("Rodrigo", "Nayely"),

              ("Mariela", "Cristian"),
              ("Mariela", "Brayan"),
              ("Mariela", "Ivan"),
              ("Mariela", "Yoseline"),
              ("Mariela", "Yessica"),
              ("Mariela", "Ever"),
              ("Mariela", "Guisela"),
              ("Mariela", "Maria"),
              ("Mariela", "Dario"),
              ("Mariela", "Belisario"),
              ("Mariela", "Jhenny"),
              ("Mariela", "Nayely"),

              ("Cristian", "Rodrigo"),
              ("Cristian", "Mariela"),
              ("Cristian", "Ivan"),
              ("Cristian", "Yoseline"),
              ("Cristian", "Yessica"),
              ("Cristian", "Ever"),
              ("Cristian", "Guisela"),
              ("Cristian", "Maria"),
              ("Cristian", "Dario"),

              ("Brayan", "Rodrigo"),
              ("Brayan", "Mariela"),
              ("Brayan", "Ivan"),
              ("Brayan", "Yoseline"),
              ("Brayan", "Yessica"),
              ("Brayan", "Ever"),
              ("Brayan", "Guisela"),
              ("Brayan", "Maria"),
              ("Brayan", "Dario"),

              ("Ivan", "Rodrigo"),
              ("Ivan", "Mariela"),
              ("Ivan", "Cristian"),
              ("Ivan", "Brayan"),
              ("Ivan", "Yessica"),
              ("Ivan", "Ever"),
              ("Ivan", "Guisela"),
              ("Ivan", "Maria"),
              ("Ivan", "Dario"),

              ("Yoseline", "Rodrigo"),
              ("Yoseline", "Mariela"),
              ("Yoseline", "Cristian"),
              ("Yoseline", "Brayan"),
              ("Yoseline", "Yessica"),
              ("Yoseline", "Ever"),
              ("Yoseline", "Guisela"),
              ("Yoseline", "Maria"),
              ("Yoseline", "Dario"),

              ("Yessica", "Rodrigo"),
              ("Yessica", "Mariela"),
              ("Yessica", "Cristian"),
              ("Yessica", "Brayan"),
              ("Yessica", "Ivan"),
              ("Yessica", "Yoseline"),
              ("Yessica", "Ever"),
              ("Yessica", "Guisela"),
              ("Yessica", "Maria"),
              ("Yessica", "Dario"),

              ("Ever", "Rodrigo"),
              ("Ever", "Mariela"),
              ("Ever", "Cristian"),
              ("Ever", "Brayan"),
              ("Ever", "Yessica"),
              ("Ever", "Ivan"),
              ("Ever", "Yoseline"),
              ("Ever", "Maria"),
              ("Ever", "Dario"),

              ("Guisela", "Rodrigo"),
              ("Guisela", "Mariela"),
              ("Guisela", "Cristian"),
              ("Guisela", "Brayan"),
              ("Guisela", "Yessica"),
              ("Guisela", "Ivan"),
              ("Guisela", "Yoseline"),
              ("Guisela", "Maria"),
              ("Guisela", "Dario"),

              ("Maria", "Rodrigo"),
              ("Maria", "Mariela"),
              ("Maria", "Cristian"),
              ("Maria", "Brayan"),
              ("Maria", "Yessica"),
              ("Maria", "Ivan"),
              ("Maria", "Yoseline"),
              ("Maria", "Ever"),
              ("Maria", "Guisela"),

              ("Dario", "Rodrigo"),
              ("Dario", "Mariela"),
              ("Dario", "Cristian"),
              ("Dario", "Brayan"),
              ("Dario", "Yessica"),
              ("Dario", "Ivan"),
              ("Dario", "Yoseline"),
              ("Dario", "Ever"),
              ("Dario", "Guisela"),

              ("Belisario", "Rodrigo"),
              ("Belisario", "Mariela"),
              ("Belisario", "Jhenny"),
              ("Belisario", "Nayely"),

              ("Jhenny", "Rodrigo"),
              ("Jhenny", "Mariela"),
              ("Jhenny", "Belisario"),

              ("Nayely", "Rodrigo"),
              ("Nayely", "Mariela"),
              ("Nayely", "Belisario"))


hijos = Relation()
facts(hijos,  ("Eddy", "Pascual"),
              ("Angel","Pascual"),
              ("Roger", "Pascual"),
              ("Reynaldo", "Pascual"),
              ("Eddy", "Norah"),
              ("Angel","Norah"),
              ("Roger", "Norah"),
              ("Reynaldo", "Norah"),

              ("Julia", "Ancelmo"),
              ("Cristina", "Ancelmo"),
              ("Miguel", "Ancelmo"),
              ("Rene", "Ancelmo"),
              ("Nansy", "Ancelmo"),
              ("Juana", "Ancelmo"),
              ("Julia", "Isabel"),
              ("Cristina", "Isabel"),
              ("Miguel", "Isabel"),
              ("Rene", "Isabel"),
              ("Nansy", "Isabel"),
              ("Juana", "Isabel"),

              ("Rodrigo", "Eddy"),
              ("Mariela", "Eddy"),
              ("Rodrigo", "Julia"),
              ("Mariela", "Julia"),

              ("Jhenny", "Roger"),
              ("Nayely", "Roger"),
              ("Jhenny", "Hilda"),
              ("Nayely", "Hilda"),

              ("Belisario", "Reynaldo"),
              ("Belisario", "Karen"),

              ("Cristian", "Migel"),
              ("Brayan", "Migel"),
              ("Cristian", "Cristina"),
              ("Brayan", "Cristina"),

              ("Ivan", "Miguel"),
              ("Yoseline", "Miguel"),
              ("Ivan", "Crissthina"),
              ("Yoseline", "Crissthina"),

              ("Yessica", "Rene"),
              ("Yessica", "Berta"),

              ("Ever", "Eduardo"),
              ("Guisela", "Eduardo"),
              ("Ever", "Nansy"),
              ("Guisela", "Nansy"),

              ("Maria", "Idelfonso"),
              ("Dario", "Idelfonso"),
              ("Maria", "Juana"),
              ("Dario", "Juana"))


print(run(0, x, padres(x, "Rodrigo")))
print(run(0, x, abuelos("Pascual", x)))
print(run(0, x, abuelos(x, "Rodrigo")))
print(run(0, x, tios(x, "Rodrigo")))
print(run(0, x, primos(x, "Rodrigo")))
print(run(0, x, hijos(x, "Eddy")))
print(run(0, x, hijos(x, "Julia")))
# Out:
# ('Julia', 'Eddy')
# ('Rodrigo', 'Nayely', 'Belisario', 'Mariela', 'Jhenny')
# ('Ancelmo', 'Isabel', 'Norah', 'Pascual')
# ('Crissthina', 'Idelfonso', 'Hilda', 'Miguel', 'Roger', 'Migel', 'Juana', 'Berta', 'Rene', 'Karen', 'Angel', 'Nansy', 'Eduardo', 'Cristina', 'Reynaldo')
# ('Yoseline', 'Jhenny', 'Ivan', 'Guisela', 'Belisario', 'Brayan', 'Dario', 'Nayely', 'Yessica', 'Maria', 'Ever', 'Cristian')
# ('Rodrigo', 'Mariela')
# ('Rodrigo', 'Mariela')
